# %%
from math import factorial

# %%
factorial(81)
# Out:
# 5797126020747367985879734231578109105412357244731625958745865049716390179693892056256184534249745940480000000000000000000

# %%
l = str(5797126020747367985879734231578109105412357244731625958745865049716390179693892056256184534249745940480000000000000000000)
len(l)

# %%
import numpy as np
import matplotlib.pyplot as plt
from time import time

# %%
cst_list = np.linspace(0.1,0.8,15)
res = [0.635, 0.635, 0.6459999999999999, 0.6249999999999999, 0.625, 0.6615000000000001, 0.613, 0.6355000000000001, 0.605, 0.5935, 0.5845, 0.568, 0.529, 0.5315, 0.5099999999999999]
total_games = 2000
plt.plot(cst_list, res, marker='o')
plt.xlabel("Exploration constant")
plt.ylabel("Win rate")
plt.title(f"UCT's win rate on {total_games} games per constant vs UCT")
#plt.savefig(f"{time()}.png")
# Out:
# Text(0.5, 1.0, "UCT's win rate on 2000 games per constant  vs UCT")

# %%
res = [0.5032, 0.5222, 0.5286, 0.5382, 0.5489999999999999, 0.5702, 0.5758000000000001, 0.5730000000000001, 0.5542, 0.568, 0.5502]
cst_list = np.linspace(0,0.5,len(res))
total_games = 5000
plt.plot(cst_list, res, marker='o')
plt.xlabel("Exploration constant")
plt.ylabel("Win rate")
plt.title(f"UCT's win rate on {total_games} games per constant vs UCT")
#plt.savefig(f"{time()}.png")
# Out:
# Text(0.5, 1.0, "UCT's win rate on 5000 games per constant vs UCT")

# %%
res = [0.511, 0.5135, 0.5385, 0.5385, 0.532, 0.5635, 0.5285, 0.5385, 0.546, 0.546, 0.5655, 0.577, 0.5765, 0.5745, 0.57, 0.57, 0.5595, 0.5515, 0.593, 0.5635, 0.5325]
cst_list = np.linspace(0,0.5,len(res))
total_games = 2000
plt.plot(cst_list, res, marker='o')
plt.xlabel("Exploration constant")
plt.ylabel("Win rate")
plt.title(f"UCT's win rate on {total_games} games per constant vs UCT")
#plt.savefig(f"{time()}.png")
# Out:
# Text(0.5, 1.0, "UCT's win rate on 2000 games per constant vs UCT")

# %%
res = [0.503, 0.5175, 0.5485, 0.519, 0.529, 0.5165, 0.5505, 0.5505, 0.5625, 0.5555, 0.5835, 0.5705, 0.578, 0.5865, 0.58, 0.583, 0.5665, 0.566, 0.5495, 0.572, 0.565]
cst_list = np.linspace(0,0.5,len(res))
total_games = 2000
plt.plot(cst_list, res, marker='o')
plt.xlabel("Exploration constant")
plt.ylabel("Win rate")
plt.title(f"UCT's win rate on {total_games} games per constant vs UCT")
#plt.savefig(f"{time()}.png")
# Out:
# Text(0.5, 1.0, "UCT's win rate on 2000 games per constant vs UCT")

# %%
res = 
cst_list = np.linspace(0,0.5,len(res))
total_games = 5000
plt.plot(cst_list, res, marker='o')
plt.xlabel("Exploration constant")
plt.ylabel("Win rate")
plt.title(f"UCT's win rate on {total_games} games per constant vs UCT")
#plt.savefig(f"{time()}.png")
# Out:
# array([0.   , 0.025, 0.05 , 0.075, 0.1  , 0.125, 0.15 , 0.175, 0.2  ,
#        0.225, 0.25 , 0.275, 0.3  , 0.325, 0.35 , 0.375, 0.4  , 0.425,
#        0.45 , 0.475, 0.5  ])

# %%
res = [0.6225, 0.647, 0.634, 0.558, 0.4945, 0.4925, 0.456, 0.44, 0.426, 0.399, 0.411, 0.394, 0.3855, 0.37, 0.3445, 0.353, 0.3365, 0.353, 0.3465, 0.3485, 0.3585] 
cst_list = np.linspace(0,4,len(res))
total_games = 2000
plt.plot(cst_list, res, marker='o')
plt.xlabel("Exploration constant")
plt.ylabel("Win rate")
plt.title(f"UCT_WM's win rate on {total_games} games per constant vs UCT")
#plt.savefig(f"{time()}.png")
# Out:
# Text(0.5, 1.0, "UCT_WM's win rate on 2000 games per constant vs UCT")

# %%
res = [0.6085, 0.605, 0.609, 0.632, 0.6425, 0.6175, 0.6305, 0.629, 0.64, 0.64, 0.6175, 0.628, 0.622, 0.635, 0.6305, 0.6005, 0.575, 0.5685, 0.6035]
cst_list = np.linspace(0,.6,len(res))
total_games = 2000
plt.plot(cst_list, res, marker='o')
plt.xlabel("Exploration constant")
plt.ylabel("Win rate")
plt.title(f"UCT's win rate on {total_games} games per constant vs UCT")
#plt.savefig(f"{time()}.png")
# Out:
# Text(0.5, 1.0, "UCT's win rate on 2000 games per constant vs UCT")

# %%
np.linspace(0,4,len(res))
# Out:
# array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4,
#        2.6, 2.8, 3. , 3.2, 3.4, 3.6, 3.8, 4. ])

# %%
res = [0.6, 0.625, 0.656, 0.571, 0.529, 0.487, 0.457, 0.425, 0.416, 0.398, 0.405, 0.382, 0.355, 0.386, 0.373, 0.356, 0.361, 0.358, 0.347, 0.336, 0.361]
cst_list = np.linspace(0,4,len(res))
total_games = 1000
plt.plot(cst_list, res, marker='o')
plt.xlabel("Exploration constant")
plt.ylabel("Win rate")
plt.title(f"uct_wm's win rate on {total_games} games per constant vs uct_wm")
#plt.savefig(f"{time()}.png")
# Out:
# Text(0.5, 1.0, "uct_wm's win rate on 1000 games per constant vs uct_wm")

# %%
cst_list = np.linspace(0,1,21)
res = [0.6025, 0.62, 0.6235, 0.636, 0.6185, 0.646, 0.63, 0.646, 0.6415, 0.628, 0.62, 0.574, 0.5785, 0.5645, 0.5305, 0.529, 0.5045, 0.497, 0.5125, 0.467, 0.475]
n = 2000
plt.plot(cst_list, res, marker="o")
plt.xlabel("Exploration constant")
plt.ylabel("uct_wm win rate")
plt.title(f"uct_wm's win rate on 2000 games per constant vs uct_wm")
# Out:
# Text(0.5, 1.0, "uct_wm's win rate on 2000 games per constant vs uct_wm")

# %%
np.linspace(0,1,21)
# Out:
# array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ,
#        0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  ])
